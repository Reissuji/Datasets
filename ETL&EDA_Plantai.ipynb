# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
df_plantsready = pd.read_csv('C:/Users/Ani/Desktop/BVNNY/Master/TFM/Datasets/PlantasMejoradasUTF.csv', sep=';')
df_plantsready.sample (10)
# Out:
#     id        Nombre_cientifico  Dificultad Ubicación  Estatura  \
# 4    5       Fittonia albivenis           2  Interior        20
# 17  18  Philodendron hederaceum           2  Interior        50
# 8    9        Phalaenopsis spp.           3  Interior        60
# 21  22         Pelargonium spp.           1  Exterior        60
# 7    8  Sansevieria trifasciata           0  Interior        90
# 10  11                Aloe vera           1  Interior        90
# 15  16    Syngonium podophyllum           1  Interior        90
# 14  15        Philodendron spp.           2  Interior       100
# 22  23             Fuchsia spp.           1  Exterior       120
# 5    6   Schlumbergera truncata           2  Interior        45
#
#     Expectativa_vida  Frecuencia_Riego  Tolera_mediterráneo_seco  \
# 4                  2                 3                         0
# 17                15                 2                         0
# 8                  7                 2                         0
# 21                 2                 2                         1
# 7                 15                 0                         1
# 10                15                 0                         1
# 15                15                 2                         0
# 14                15                 2                         0
# 22                 2                 2                         0
# 5                 20                 1                         0
#
#     Adecuado_para_mascotas Estilo_decorativo Sensación
# 4                        1     Contemporáneo     Ambos
# 17                       0          Tropical    Cálido
# 8                        0          Elegante    Cálido
# 21                       0      Mediterránep    Cálido
# 7                        0       Minimalista      Frío
# 10                       0           Natural      Frío
# 15                       0           Moderno      Frío
# 14                       0          Tropical    Cálido
# 22                       1        Victoriano    Cálido
# 5                        1           Rústico    Cálido

# %%
df_encuesta=pd.read_csv('C:/Users/Ani/Desktop/BVNNY/Master/TFM/Datasets/Encuesta.csv', sep=',')
df_encuesta.sample(10)
# Out:
#                     Marca temporal  Genero   Origen              Edad  \
# 128  2024/05/04 5:02:20 p. m. EEST  Hombre   España           18 – 25
# 195  2024/05/04 9:33:32 p. m. EEST  Hombre   España           18 – 25
# 121  2024/05/04 4:39:55 p. m. EEST  Hombre   España           26 – 30
# 78   2024/05/04 3:36:45 p. m. EEST  Hombre  Rumania           18 – 25
# 138  2024/05/04 5:38:30 p. m. EEST  Hombre   España           26 – 30
# 317  2024/05/07 2:22:26 p. m. EEST   Mujer   España  Menos de 18 años
# 69   2024/05/04 3:31:07 p. m. EEST  Hombre   España           18 – 25
# 244  2024/05/05 1:48:22 a. m. EEST  Hombre   España           18 – 25
# 123  2024/05/04 4:44:55 p. m. EEST  Hombre   España           18 – 25
# 63   2024/05/04 3:25:49 p. m. EEST  Hombre   España           18 – 25
#
#     Independencia_economica  \
# 128                      No
# 195                      No
# 121                      Sí
# 78                       Sí
# 138                      Sí
# 317                      No
# 69                       Sí
# 244                      No
# 123                      Sí
# 63                       No
#
#                                                  Clima Cantidad_plantas  \
# 128  Mediterráneo “continentalizado” (por ejemplo: ...                1
# 195  Atlántico (por ejemplo: San Sebastián, Gijón, ...              2-5
# 121  Mediterráneo “continentalizado” (por ejemplo: ...              +10
# 78   Mediterráneo “continentalizado” (por ejemplo: ...             6-10
# 138  Mediterráneo seco (por ejemplo: Alicante, Murc...                1
# 317  Atlántico (por ejemplo: San Sebastián, Gijón, ...              +10
# 69   Mediterráneo típico (por ejemplo: Barcelona, V...                1
# 244  Mediterráneo “continentalizado” (por ejemplo: ...              +10
# 123  Mediterráneo “continentalizado” (por ejemplo: ...                0
# 63   Subtropical (por ejemplo: Santa Cruz de Teneri...              2-5
#
#     Parte_predominante_casa Conocimiento_sobre_plantas  \
# 128                Interior     Tengo nociones básicas
# 195                Exterior     Tengo nociones básicas
# 121                Exterior                       Nada
# 78                 Exterior     Tengo nociones básicas
# 138                Exterior     Tengo nociones básicas
# 317         Ambos por igual         Soy un/a experto/a
# 69                 Interior                       Nada
# 244                Exterior    Me dedico a la botánica
# 123                Exterior     Tengo nociones básicas
# 63                 Interior   Me he informado bastante
#
#                                   Plantas_recomendadas  ...  \
# 128  Cactus de Navidad;Violeta africana;Orquídea ph...  ...
# 195  Costilla de Adán;Cactus de Navidad;Orquídea ph...  ...
# 121  Helecho de Boston;Planta de serpiente/ Espada ...  ...
# 78                                          Espatifilo  ...
# 138  Espatifilo;Filodendro;Peperomia;Pilea;Cactus d...  ...
# 317  Tradescantia;Aeonium;Echeveria;Geranio;Fucsia;...  ...
# 69                                      Palo de Brasil  ...
# 244  Helecho de Boston;Pilea;Pothos;Planta de serpi...  ...
# 123  Planta de serpiente/ Espada de San Jorge;Cactu...  ...
# 63   Helecho de Boston;Costilla de Adán;Fittonia;Ca...  ...
#
#                                    Adquisicion_plantas  \
# 128                                      Fue un regalo
# 195                                 Me la recomendaron
# 121  Decoración;Mejorar la calidad del aire;Perfuma...
# 78   Decoración;Mejorar la calidad del aire;Me la r...
# 138                                         Decoración
# 317  Decoración;Por sus frutos/ especies aromáticas...
# 69                                          Decoración
# 244  Decoración;Mejorar la calidad del aire;Por sus...
# 123                                         Decoración
# 63    Decoración;Perfumar el entorno;La planté de cero
#
#                        Atencion_plantas           Respuesta_planta_mustia  \
# 128                   Cuando me acuerdo  Me informo de qué le puede pasar
# 195                   Cuando me acuerdo                      Le echo agua
# 121                   Cuando me acuerdo                      Le echo agua
# 78                    Cuando me acuerdo                     Le hecho agua
# 138                   Cuando me acuerdo                      Le echo agua
# 317              Les hago bastante caso  Me informo de qué le puede pasar
# 69                     La verdad que no  Me informo de qué le puede pasar
# 244              Les hago bastante caso  Me informo de qué le puede pasar
# 123                   Cuando me acuerdo                      Le echo agua
# 63   Todos los días compruebo su estado  Me informo de qué le puede pasar
#
#                      Prefiere_florecer  Preferencia_tonos  \
# 128                                 Si            Cálidos
# 195                                 Si              Fríos
# 121                                 Si              Fríos
# 78   No, prefiero que no tengan flores            Cálidos
# 138                  Me es indiferente            Cálidos
# 317                  Me es indiferente            Cálidos
# 69   No, prefiero que no tengan flores              Fríos
# 244                  Me es indiferente            Cálidos
# 123                  Me es indiferente  Me es indiferente
# 63                                  Si            Cálidos
#
#                   Tiempo_para_ti Paciencia Sentimientos_adquisicion  \
# 128  Tengo bastante tiempo libre        Si                  Alegría
# 195   Tengo algo de tiempo libre        Si             Indiferencia
# 121   Tengo algo de tiempo libre        Si              Realización
# 78         No tengo tiempo libre        Si             Indiferencia
# 138   Tengo algo de tiempo libre        Si                  Alegría
# 317   Tengo algo de tiempo libre        Si                  Alegría
# 69    Tengo algo de tiempo libre        No             Indiferencia
# 244   Tengo algo de tiempo libre        Si                  Alegría
# 123   Tengo algo de tiempo libre        No                  Alegría
# 63   Tengo bastante tiempo libre        Si                  Alegría
#
#     Duracion_plantas Tipo_vivienda
# 128             Años   Apartamento
# 195            Meses   Apartamento
# 121             Años        Chalet
# 78              Años   Apartamento
# 138             Años   Apartamento
# 317             Años        Chalet
# 69              Años   Apartamento
# 244             Años       Adosado
# 123          Semanas   Apartamento
# 63             Meses   Apartamento
#
# [10 rows x 21 columns]

# %%
df_encuesta = df_encuesta.drop(columns=['Marca temporal'])
