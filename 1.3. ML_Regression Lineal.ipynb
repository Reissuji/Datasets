# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
df_regr = pd.read_csv('C:/Users/Ani/Desktop/BVNNY/Master/TFM/Datasets/df_final.csv', sep=',')

# %%
df_regr
# Out:
#         Especie_planta  Toxic_Yes  Conocimiento_sobre_plantas_enc  \
# 0     Costilla de Adán        0.0                             1.0
# 1     Costilla de Adán        1.0                             1.0
# 2     Costilla de Adán        1.0                             1.0
# 3     Costilla de Adán        0.0                             1.0
# 4     Costilla de Adán        1.0                             1.0
# ...                ...        ...                             ...
# 1290             Hosta        0.0                             1.0
# 1291             Hosta        1.0                             1.0
# 1292             Hosta        0.0                             2.0
# 1293             Hosta        1.0                             2.0
# 1294             Hosta        1.0                             1.0
#
#       Tiempo_de_dedicacion_enc  Vive_En_Clima_No_Seco  Tonos_Cálidos  \
# 0                          1.0                      1              0
# ...

# %%
df_regr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295 entries, 0 to 1294
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Especie_planta                  1295 non-null   object
#  1   Toxic_Yes                       1295 non-null   float64
#  2   Conocimiento_sobre_plantas_enc  1295 non-null   float64
#  3   Tiempo_de_dedicacion_enc        1295 non-null   float64
#  4   Vive_En_Clima_No_Seco           1295 non-null   int64
#  5   Tonos_Cálidos                   1295 non-null   int64
#  6   Tonos_Fríos                     1295 non-null   int64
#  7   Tonos_Me es indiferente         1295 non-null   int64
#  8   Vivienda_Adosado                1295 non-null   int64
#  9   Vivienda_Apartamento            1295 non-null   int64
#  10  Vivienda_Chalet                 1295 non-null   int64
#  11  Dificultad                      1295 non-null   int64
# ...

# %%
df_regr.describe()
# Out:
#          Toxic_Yes  Conocimiento_sobre_plantas_enc  Tiempo_de_dedicacion_enc  \
# count  1295.000000                     1295.000000               1295.000000
# mean      0.558301                        1.187645                  1.583784
# std       0.496781                        0.766071                  0.745237
# min       0.000000                        0.000000                  0.000000
# 25%       0.000000                        1.000000                  1.000000
# 50%       1.000000                        1.000000                  2.000000
# 75%       1.000000                        1.000000                  2.000000
# max       1.000000                        3.000000                  3.000000
#
#        Vive_En_Clima_No_Seco  Tonos_Cálidos  Tonos_Fríos  \
# count            1295.000000    1295.000000  1295.000000
# mean                0.865637       0.318919     0.240154
# std                 0.341174       0.466238     0.427342
# ...

# %%
df_regr.hist(figsize=(20, 30), color= "pink")
# Out:
# array([[<Axes: title={'center': 'Toxic_Yes'}>,
#         <Axes: title={'center': 'Conocimiento_sobre_plantas_enc'}>,
#         <Axes: title={'center': 'Tiempo_de_dedicacion_enc'}>,
#         <Axes: title={'center': 'Vive_En_Clima_No_Seco'}>],
#        [<Axes: title={'center': 'Tonos_Cálidos'}>,
#         <Axes: title={'center': 'Tonos_Fríos'}>,
#         <Axes: title={'center': 'Tonos_Me es indiferente'}>,
#         <Axes: title={'center': 'Vivienda_Adosado'}>],
#        [<Axes: title={'center': 'Vivienda_Apartamento'}>,
#         <Axes: title={'center': 'Vivienda_Chalet'}>,
#         <Axes: title={'center': 'Dificultad'}>,
#         <Axes: title={'center': 'Ubicación'}>],
#        [<Axes: title={'center': 'Estatura'}>,
#         <Axes: title={'center': 'Frecuencia_Riego'}>,
#         <Axes: title={'center': 'Tolera_mediterráneo_seco'}>,
#         <Axes: title={'center': 'Adecuado_para_mascotas'}>],
#        [<Axes: title={'center': 'Sensación'}>, <Axes: >, <Axes: >,
# ...

# %%
plt.scatter(x = df_regr["Conocimiento_sobre_plantas_enc"], y = df_regr["Especie_planta"], color = "pink")
plt.title("Conocimiento vs Especie Recomendada")
plt.xlabel("Conocimiento_sobre_plantas_enc")
plt.ylabel("Especie_planta")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x = df_regr["Dificultad"], y = df_regr["Especie_planta"], color = "pink")
plt.title("Dificultad vs Especie Recomendada")
plt.xlabel("Dificultad")
plt.ylabel("Especie_planta")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Realmente no aportan informacion

# %%
#usamos Conocimiento_sobre_plantas_enc, Tiempo_de_dedicacion_enc, Vive_En_Clima_No_Seco

# %% [markdown]
# ## Dividimos en datos de entrenamiento y datos de testeo

# %%
#cogemos 80% para modelo y 20% de test
datos_entrenamiento= df_regr.sample(frac=0.8, random_state=0)
datos_test= df_regr.drop(datos_entrenamiento.index)
datos_entrenamiento
# Out:
#          Especie_planta  Toxic_Yes  Conocimiento_sobre_plantas_enc  \
# 936           Peperomia        1.0                             2.0
# 474             Lavanda        0.0                             1.0
# 1028         Nephthytis        0.0                             2.0
# 240           Aloe vera        1.0                             0.0
# 1254       Philodendron        1.0                             0.0
# ...                 ...        ...                             ...
# 455             Lavanda        0.0                             1.0
# 584             Geranio        0.0                             1.0
# 147   Cactus de Navidad        1.0                             1.0
# 160   Cactus de Navidad        0.0                             2.0
# 750   Helecho de Boston        0.0                             1.0
#
#       Tiempo_de_dedicacion_enc  Vive_En_Clima_No_Seco  Tonos_Cálidos  \
# 936                        1.0                      1              0
# ...

# %%
etiquetas_entrenamiento = datos_entrenamiento.pop("Especie_planta")
etiquetas_test= datos_test.pop("Especie_planta")

# %%
etiquetas_entrenamiento
# Out:
# 936             Peperomia
# 474               Lavanda
# 1028           Nephthytis
# 240             Aloe vera
# 1254         Philodendron
#               ...
# 455               Lavanda
# 584               Geranio
# 147     Cactus de Navidad
# 160     Cactus de Navidad
# 750     Helecho de Boston
# Name: Especie_planta, Length: 1036, dtype: object

# %%
datos_entrenamiento
# Out:
#       Toxic_Yes  Conocimiento_sobre_plantas_enc  Tiempo_de_dedicacion_enc  \
# 936         1.0                             2.0                       1.0
# 474         0.0                             1.0                       1.0
# 1028        0.0                             2.0                       2.0
# 240         1.0                             0.0                       2.0
# 1254        1.0                             0.0                       2.0
# ...         ...                             ...                       ...
# 455         0.0                             1.0                       2.0
# 584         0.0                             1.0                       1.0
# 147         1.0                             1.0                       2.0
# 160         0.0                             2.0                       2.0
# 750         0.0                             1.0                       2.0
#
#       Vive_En_Clima_No_Seco  Tonos_Cálidos  Tonos_Fríos  \
# ...

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit (datos_entrenamiento,etiquetas_entrenamiento)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 modelo = LinearRegression()
# ----> 3 modelo.fit (datos_entrenamiento,etiquetas_entrenamiento)
#
# File c:\Users\Ani\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Ani\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
# ...
